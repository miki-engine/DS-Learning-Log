# %% [markdown]
# # 3次元リスト：春の花のデータ分析

# %%
# [地域][年度][[花(サクラ,チューリップ,ナノハナ)]
flower_data = [
    [ # 0番目：東京
        [100, 50, 30], #0番目 :2024年
        [120, 60, 40], #1番目 :2025年
    ],
    [ # 1番目 :京都
        [80, 70, 20], #0番目 :2024年
        [90, 80, 25], #1番目 :2025年
    ]
]
# ターゲット :京都・2024年・ナノハナ
target = flower_data[1][0][2]
print(f"ターゲットの開花数:{target}本")
# Out:
# ターゲットの開花数:20本

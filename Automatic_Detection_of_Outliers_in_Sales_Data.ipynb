# %% [markdown]
# # Automatic Detection of Outliers in Sales Data

# %%
# Daily sales data（Amount: sales Amount）
daily_sales = [
    {"day": "Day 1", "amount": 52000},
    {"day": "Day 2", "amount": 48000},
    {"day": "Day 3", "amount": 150000},  # abnormaly high（special sale day, etc）
    {"day": "Day 4", "amount": 51000},
    {"day": "Day 5", "amount": 5000},    # abnormaly low（System error, etc）
    {"day": "Day 6", "amount": 49000},
]

# total sales
total = {"count": 0, "total": 0}
for sale in daily_sales:
    total["count"] += 1
    total["total"] += sale["amount"]

def calculate_average(total, count):
    """Calculate the average sales"""
    return total / count

def detect_abnomaly(amount, average):
    """Detect outliers"""



print(total)
# Out:
# {'count': 6, 'total': 355000}

# %% [markdown]
# # 商品売上のランク分類

# %%
sales_data = [
    {"item": "Monitor A", "price": 35000, "quantity": 10},
    {"item": "Mouse B", "price": 5000, "quantity": 50},
    {"item": "Keyboard C", "price": 12000, "quantity": 20},
    {"item": "Laptop D", "price": 150000, "quantity": 5},
    {"item": "Cable E", "price": 1500, "quantity": 100},
    {"item": "Webcam F", "price": 8000, "quantity": 15},
    {"item": "Desk G", "price": 45000, "quantity": 3},
    {"item": "Earphone H", "price": 25000, "quantity": 12},
]

# 1. 各商品の売上を計算して追加
for item in sales_data:
    item["sales"] = item["price"] * item["quantity"]

# 2. 総売上額を計算
total_sales = sum(item["sales"] for item in sales_data)

# 3.売上で降順に並び替え
sorted_data = sorted(sales_data, key=lambda x: x["sales"], reverse=True)
print(sorted_data)
# Out:
# [{'item': 'Laptop D', 'price': 150000, 'quantity': 5, 'sales': 750000}, {'item': 'Monitor A', 'price': 35000, 'quantity': 10, 'sales': 350000}, {'item': 'Earphone H', 'price': 25000, 'quantity': 12, 'sales': 300000}, {'item': 'Mouse B', 'price': 5000, 'quantity': 50, 'sales': 250000}, {'item': 'Keyboard C', 'price': 12000, 'quantity': 20, 'sales': 240000}, {'item': 'Cable E', 'price': 1500, 'quantity': 100, 'sales': 150000}, {'item': 'Desk G', 'price': 45000, 'quantity': 3, 'sales': 135000}, {'item': 'Webcam F', 'price': 8000, 'quantity': 15, 'sales': 120000}]

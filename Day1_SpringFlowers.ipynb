# %% [markdown]
# # DS学習：１日目
# ## テーマ：春の花のリスト作成とデータフレーム化
# - 目的：Pythonの基本構造である「リスト」と「辞書」を学び、Pandasで表を作成する

# %%
import pandas as pd

# 1. 春の花のデータを「辞書形式」で作る
flower_data = {
    '花の名前':['サクラ', 'チューリップ', 'ナノハナ', 'シバザクラ',],
    '開花時期':['３月下旬', '４月上旬', '３月中旬', '４月中旬',],
    '色':['ピンク', '赤', '黄色', '紫',]}
#2. Pandasを使って「表(DataFrame)」に変換する
df = pd.DataFrame(flower_data)
#3. 表示させる
df
# Out:
#      花の名前  開花時期    色
# 0     サクラ  ３月下旬  ピンク
# 1  チューリップ  ４月上旬    赤
# 2    ナノハナ  ３月中旬   黄色
# 3   シバザクラ  ４月中旬    紫
